# %%
df_q1.head().to_clipboard(sep=",")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_q1.head().to_clipboard(sep=",")
#
# NameError: name 'df_q1' is not defined

# %%
df_q1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_q1
#
# NameError: name 'df_q1' is not defined
